# %%
from src.trainer import Trainer

# %%
trainer = Trainer()

# %%
trainer.train()
# Out:
# squre: 0.46 | Adj R square: 0.45 | Best RMSE: 7189.55
#
# Epoch 1868
# Batch 12/12 | Cost: 2729.719970703125
# Evaluation || MAE: 5691.42 | RMSE: 8234.96 | R squre: 0.53 | Adj R square: 0.52 | Best RMSE: 7189.55
#
# Epoch 1869
# Batch 12/12 | Cost: 2355.156005859375
# Evaluation || MAE: 5410.95 | RMSE: 7988.48 | R squre: 0.44 | Adj R square: 0.42 | Best RMSE: 7189.55
#
# Epoch 1870
# Batch 12/12 | Cost: 5171.10986328125
# Evaluation || MAE: 5705.87 | RMSE: 8265.01 | R squre: 0.54 | Adj R square: 0.53 | Best RMSE: 7189.55
#
# Epoch 1871
# Batch 12/12 | Cost: 4864.31298828125
# Evaluation || MAE: 5201.56 | RMSE: 7786.33 | R squre: 0.37 | Adj R square: 0.35 | Best RMSE: 7189.55
#
# Epoch 1872
# Batch 12/12 | Cost: 5478.5947265625
# Evaluation || MAE: 5513.11 | RMSE: 8090.71 | R squre: 0.48 | Adj R square: 0.46 | Best RMSE: 7189.55
#
# Epoch 1873
# Batch 12/12 | Cost: 3535.03076171875
# Evaluation || MAE: 5395.64 | RMSE: 7968.67 | R squre: 0.43 | Adj R square: 0.42 | Best RMSE: 7189.55
# ...

# %%
eval = Trainer("results/weights/model_weight.pt")

# %%
eval.evaluate()
# Out:
# Evaluation || MAE: 4367.69 | RMSE: 7189.55 | R squre: 0.17 | Adj R square: 0.14 | Best RMSE: 7189.55
# True
